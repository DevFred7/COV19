# %% [markdown]
# # The State of COVID-19 in India

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import matplotlib as mpl
from matplotlib import pyplot as plt
from ipywidgets import interact
from ipywidgets import fixed
import seaborn as sns
import calendar as cal

# %%
import numpy as np
import pandas as pd
#import missingno as msno
import re
import os, sys

# %%
import warnings
import json

warnings.filterwarnings('ignore')
sns.set_context("poster")
plt.style.use('fivethirtyeight')

s = json.load(open("../styles/bmh_matplotlibrc.json"))
plt.rcParams.update(s)

# %%
covid19 = pd.read_excel('../data/covid_19.xlsx')
covid19.head(100)
# Out:
#     Patient Number State Patient Number       Date Announced Age Bracket  \
# 0                1             KL-TS-P1           30/01/2020          20
# 1                2             KL-AL-P1  2020-02-02 00:00:00         NaN
# 2                3             KL-KS-P1  2020-03-02 00:00:00         NaN
# 3                4                DL-P1  2020-02-03 00:00:00          45
# 4                5                TS-P1  2020-02-03 00:00:00          24
# ..             ...                  ...                  ...         ...
# 95              96                  NaN           14/03/2020          59
# 96              97                  NaN           14/03/2020         NaN
# 97              98                  NaN           14/03/2020          43
# 98              99                  NaN           14/03/2020         NaN
# 99             100                  NaN           14/03/2020         NaN
#
#    Gender             Detected City Detected District Detected State  \
# 0       F                  Thrissur          Thrissur         Kerala
# 1     NaN                 Alappuzha         Alappuzha         Kerala
# 2     NaN                 Kasaragod         Kasaragod         Kerala
# 3       M  East Delhi (Mayur Vihar)        East Delhi          Delhi
# 4       M                 Hyderabad         Hyderabad      Telangana
# ..    ...                       ...               ...            ...
# 95    NaN                    Mumbai            Mumbai    Maharashtra
# 96    NaN                    Mumbai            Mumbai    Maharashtra
# 97      M                    Nagpur            Nagpur    Maharashtra
# 98      F                      Pune              Pune    Maharashtra
# 99      F                      Pune              Pune    Maharashtra
#
#    Current Status                                              Notes  \
# 0       Recovered                               Travelled from Wuhan
# 1       Recovered                               Travelled from Wuhan
# 2       Recovered                               Travelled from Wuhan
# 3       Recovered                      Travelled from Austria, Italy
# 4       Recovered  Travelled from Dubai to Bangalore on 20th Feb,...
# ..            ...                                                ...
# 95   Hospitalized  Travelled from Philippines and were brought in...
# 96   Hospitalized  Have international history and were brought in...
# 97   Hospitalized        Travelled from US, travelled along with P78
# 98   Hospitalized  First contacts or family members of the group ...
# 99   Hospitalized  First contacts or family members of the group ...
#
#    Contracted from which Patient (Suspected) Nationality Type of transmission  \
# 0                                        NaN       India             Imported
# 1                                        NaN       India             Imported
# 2                                        NaN       India             Imported
# 3                                        NaN       India             Imported
# 4                                        NaN       India             Imported
# ..                                       ...         ...                  ...
# 95                                       NaN       India             Imported
# 96                                       NaN       India             Imported
# 97                                       P78       India             Imported
# 98                                       NaN       India                Local
# 99                                       NaN       India                Local
#
#      Status Change Date                                           Source_1  \
# 0            14/02/2020  https://twitter.com/vijayanpinarayi/status/122...
# 1            14/02/2020  https://www.indiatoday.in/india/story/kerala-r...
# 2            14/02/2020  https://www.indiatoday.in/india/story/kerala-n...
# 3            15/03/2020  https://www.indiatoday.in/india/story/not-a-ja...
# 4   2020-02-03 00:00:00  https://www.deccanherald.com/national/south/qu...
# ..                  ...                                                ...
# 95           14/03/2020  https://www.indiatoday.in/india/story/four-new...
# 96           14/03/2020  https://www.indiatoday.in/india/story/four-new...
# 97           14/03/2020  https://www.indiatoday.in/india/story/1-more-t...
# 98           14/03/2020  https://twitter.com/ANI/status/123888256798766...
# 99           14/03/2020  https://twitter.com/ANI/status/123888256798766...
#
#                                              Source_2  \
# 0   https://weather.com/en-IN/india/news/news/2020...
# 1   https://weather.com/en-IN/india/news/news/2020...
# 2   https://twitter.com/ANI/status/122422148580539...
# 3   https://economictimes.indiatimes.com/news/poli...
# 4   https://www.indiatoday.in/india/story/coronavi...
# ..                                                ...
# 95  https://www.thehindu.com/todays-paper/tp-natio...
# 96  https://www.thehindu.com/todays-paper/tp-natio...
# 97  https://www.thehindu.com/news/national/coronav...
# 98  https://www.hindustantimes.com/india-news/5-ne...
# 99  https://www.hindustantimes.com/india-news/5-ne...
#
#                                              Source_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2   https://weather.com/en-IN/india/news/news/2020...
# 3                                                 NaN
# 4   https://www.thehindu.com/news/national/coronav...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                          Backup Notes
# 0                                  Student from Wuhan
# 1                                  Student from Wuhan
# 2                                  Student from Wuhan
# 3                 Travel history to Italy and Austria
# 4          Travel history to Dubai, Singapore contact
# ..                                                ...
# 95  Travel history to Philippines and were brought...
# 96  Have international travel history and were bro...
# 97         Returned from US, travelled along with P78
# 98  First contacts or family members of the group ...
# 99  First contacts or family members of the group ...
#
# [100 rows x 18 columns]

# %%
covid19.describe(include='all').T
# Out:
#                                           count unique  \
# Patient Number                             1619    NaN
# State Patient Number                        409    404
# Date Announced                             1619     33
# Age Bracket                                 618     78
# Gender                                      741      2
# Detected City                               718    199
# Detected District                          1286    179
# Detected State                             1619     29
# Current Status                             1619      4
# Notes                                      1611    528
# Contracted from which Patient (Suspected)   411    100
# Nationality                                 420      9
# Type of transmission                       1606      3
# Status Change Date                         1616     29
# Source_1                                   1554    430
# Source_2                                    687    228
# Source_3                                    145     72
# Backup Notes                                361    221
#
#                                                                                          top  \
# Patient Number                                                                           NaN
# State Patient Number                                                               KL-TV-R10
# Date Announced                                                                    31/03/2020
# Age Bracket                                                                               21
# Gender                                                                                     M
# Detected City                                                                         Mumbai
# Detected District                                                                  Kasaragod
# Detected State                                                                   Maharashtra
# Current Status                                                                  Hospitalized
# Notes                                                                        Details awaited
# Contracted from which Patient (Suspected)                                                 E0
# Nationality                                                                            India
# Type of transmission                                                                     TBD
# Status Change Date                                                                31/03/2020
# Source_1                                   https://twitter.com/Vijayabaskarofl/status/124...
# Source_2                                   https://www.facebook.com/permalink.php?story_f...
# Source_3                                   https://www.facebook.com/CollectorKNR/posts/28...
# Backup Notes                                                                 Details awaited
#
#                                            freq mean      std  min    25%  \
# Patient Number                              NaN  810  467.509    1  405.5
# State Patient Number                          2  NaN      NaN  NaN    NaN
# Date Announced                              272  NaN      NaN  NaN    NaN
# Age Bracket                                  25  NaN      NaN  NaN    NaN
# Gender                                      524  NaN      NaN  NaN    NaN
# Detected City                                67  NaN      NaN  NaN    NaN
# Detected District                           109  NaN      NaN  NaN    NaN
# Detected State                              302  NaN      NaN  NaN    NaN
# Current Status                             1540  NaN      NaN  NaN    NaN
# Notes                                       404  NaN      NaN  NaN    NaN
# Contracted from which Patient (Suspected)   114  NaN      NaN  NaN    NaN
# Nationality                                 365  NaN      NaN  NaN    NaN
# Type of transmission                        685  NaN      NaN  NaN    NaN
# Status Change Date                          272  NaN      NaN  NaN    NaN
# Source_1                                     50  NaN      NaN  NaN    NaN
# Source_2                                     34  NaN      NaN  NaN    NaN
# Source_3                                     15  NaN      NaN  NaN    NaN
# Backup Notes                                 33  NaN      NaN  NaN    NaN
#
#                                            50%     75%   max
# Patient Number                             810  1214.5  1619
# State Patient Number                       NaN     NaN   NaN
# Date Announced                             NaN     NaN   NaN
# Age Bracket                                NaN     NaN   NaN
# Gender                                     NaN     NaN   NaN
# Detected City                              NaN     NaN   NaN
# Detected District                          NaN     NaN   NaN
# Detected State                             NaN     NaN   NaN
# Current Status                             NaN     NaN   NaN
# Notes                                      NaN     NaN   NaN
# Contracted from which Patient (Suspected)  NaN     NaN   NaN
# Nationality                                NaN     NaN   NaN
# Type of transmission                       NaN     NaN   NaN
# Status Change Date                         NaN     NaN   NaN
# Source_1                                   NaN     NaN   NaN
# Source_2                                   NaN     NaN   NaN
# Source_3                                   NaN     NaN   NaN
# Backup Notes                               NaN     NaN   NaN

# %%
data_copy = covid19.copy()
id(data_copy) == id(covid19)
# Out:
# False

# %%
data_copy.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes'],
#       dtype='object')

# %%
data_copy.drop(['Source_1', 'Source_2', 'Source_3'], axis=1, inplace=True)
data_copy.head()
# Out:
#    Patient Number State Patient Number       Date Announced Age Bracket  \
# 0               1             KL-TS-P1           30/01/2020          20
# 1               2             KL-AL-P1  2020-02-02 00:00:00         NaN
# 2               3             KL-KS-P1  2020-03-02 00:00:00         NaN
# 3               4                DL-P1  2020-02-03 00:00:00          45
# 4               5                TS-P1  2020-02-03 00:00:00          24
#
#   Gender             Detected City Detected District Detected State  \
# 0      F                  Thrissur          Thrissur         Kerala
# 1    NaN                 Alappuzha         Alappuzha         Kerala
# 2    NaN                 Kasaragod         Kasaragod         Kerala
# 3      M  East Delhi (Mayur Vihar)        East Delhi          Delhi
# 4      M                 Hyderabad         Hyderabad      Telangana
#
#   Current Status                                              Notes  \
# 0      Recovered                               Travelled from Wuhan
# 1      Recovered                               Travelled from Wuhan
# 2      Recovered                               Travelled from Wuhan
# 3      Recovered                      Travelled from Austria, Italy
# 4      Recovered  Travelled from Dubai to Bangalore on 20th Feb,...
#
#   Contracted from which Patient (Suspected) Nationality Type of transmission  \
# 0                                       NaN       India             Imported
# 1                                       NaN       India             Imported
# 2                                       NaN       India             Imported
# 3                                       NaN       India             Imported
# 4                                       NaN       India             Imported
#
#     Status Change Date                                Backup Notes
# 0           14/02/2020                          Student from Wuhan
# 1           14/02/2020                          Student from Wuhan
# 2           14/02/2020                          Student from Wuhan
# 3           15/03/2020         Travel history to Italy and Austria
# 4  2020-02-03 00:00:00  Travel history to Dubai, Singapore contact

# %% [markdown]
# ## Questions
#
# * [x] Total cases per day
# * [ ] Monthly status report

# %%
cases_per_day = data_copy[['Date Announced', 'Patient Number']].groupby('Date Announced').sum()

# %%
cases_per_day.reset_index(inplace=True)
cases_per_day['Mon'] = cases_per_day['Date Announced'].apply(lambda x: x.month)
cases_per_day['Month'] = cases_per_day['Mon'].apply(lambda x: cal.month_abbr[x])
cases_per_day.head()
# Out:
#   Date Announced  Patient Number  Mon Month
# 0     2020-01-30               1    1   Jan
# 1     2020-02-02               2    2   Feb
# 2     2020-02-03               9    2   Feb
# 3     2020-03-02               3    3   Mar
# 4     2020-03-03               6    3   Mar

# %%
cases_per_day['Day'] = cases_per_day['Date Announced'].apply(lambda x: x.day)

# %%
data = cases_per_day.where(cases_per_day['Month'] == 'Mar').dropna()

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
_ = sns.lineplot(x='Day', y='Patient Number', data=data, ax=ax)
_ = plt.ylabel('Number of Cases', fontsize='small')
_ = plt.yticks(fontsize='small')
_ = plt.xlabel('Day of Month')
_ = plt.title('March 2020: Announced Cases by Day', fontsize='medium', loc='left')

# %%
data_copy['Month Announced'] = pd.DatetimeIndex(data_copy['Date Announced']).month
data_copy['Month Name Announced'] = data_copy['Month Announced'].apply(lambda x: cal.month_abbr[x])

# %%
month_summ = data_copy.groupby(['Month Name Announced'])['Current Status'].value_counts().unstack().fillna(0)

# %%
month_summ = np.log(month_summ[['Deceased', 'Hospitalized', 'Migrated', 'Recovered']])

# %%
month_summ.replace([np.inf, -np.inf], 0, inplace=True)

# %%
fig, ax = plt.subplots(1, figsize=(10,8))
_ = month_summ.plot(kind='bar', stacked=True, rot=0,
                    color=[ '#1e90ff', '#00bfff', '#1efffe', '#1e20ff'], ax=ax)
_ = plt.ylabel('Number of Cases - log(x)', fontsize='small')
_ = plt.yticks(fontsize='small')
_ = plt.xlabel('Month')
_ = plt.title('2020 Monthly Report Summary: Patient Statuses', fontsize='medium', loc='left')

# %% [markdown]
# The y-axis viewed in the form of log-scale because March figures were skewing the results. This visualization is only meant to show the general pattern, not exact figures.
